# %%
import os, json
import pandas as pd
import boto3
import geopandas as gpd

from math import floor
from pystac_client import Client
import planetary_computer as pc
import numpy as np
import rasterio
import requests, pyproj
from pyproj.aoi import AreaOfInterest
from pyproj.database import query_utm_crs_info
from rasterio.merge import merge as rmerge
import rasterio.mask
from rasterio.features import shapes
from shapely.geometry import Polygon, MultiPolygon, box, shape
from shapely.ops import transform, unary_union
import networkx as nx

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
CONNECTIVITY_DISTANCE = 100    # Max distance two patches can be apart and be considered connected (meter)
MIN_PATCHSIZE = 10000    # Min patch size to be included in analysis (sq meter)

# %%
# define directory
out_dir = os.getcwd()
bucket_name = 'cities-indicators'
aws_s3_dir = "https://"+bucket_name+".s3.eu-west-3.amazonaws.com"
boundary_ext = '/data/boundaries/'
indicators_file_aws = 'indicators/indicators.csv'

# %%
OUTPUT_FILENAME = 'BIO_2_habitat_connectivity.csv'

# %%
# get list of cities
boundary_georef = pd.read_csv(aws_s3_dir + boundary_ext + 'boundary_georef.csv')
boundary_georef
# Out:
#     Unnamed: 0           geo_name   level aoi_boundary_name  \
# 0            1        ARG-Mendoza  region         ADM3union
# 1            2  ARG-Mar_del_Plata    city              ADM3
# 2            3        ARG-Ushuaia    city              ADM4
# 3            4          ARG-Salta  region         ADM2union
# 4            5   ARG-Buenos_Aires  region         ADM2union
# 5            6       BRA-Teresina    city         ADM4union
# 6            7  BRA-Florianopolis    city         ADM4union
# 7            8          BRA-Belem    city         ADM4union
# 8            9       CRI-San_Jose  region         ADM2union
# 9           10         RWA-Kigali    city         ADM4union
# 10          11       SLE-Freetown    city     ADM4cityunion
# 11          12      MAR-Marrakech     NaN              ADM2
# 12          13        IND-Chennai  region         ADM4union
# 13          14           IND-Pune  region         ADM4union
# 14          15          IND-Surat  region         ADM4union
# 15          16        CHN-Chengdu     NaN         ADM3union
# 16          17      CHN-Chongqing     NaN              ADM1
# 17          18         CHN-Ningbo     NaN         ADM3union
# 18          19        IDN-Jakarta     NaN         ADM4union
# 19          20         IDN-Bitung     NaN              ADM2
# 20          21       IDN-Semarang     NaN              ADM1
# 21          22     IDN-Balikpapan     NaN         ADM4union
# 22          23      IDN-Palembang     NaN              ADM2
# 23          24       BRA-Salvador     NaN         ADM4union
# 24          25         COD-Bukavu     NaN         ADM3union
# 25          26          COD-Uvira     NaN         ADM3union
# 26          27    COG-Brazzaville     NaN         ADM4union
# 27          28   COL-Barranquilla     NaN         ADM4union
# 28          29    ETH-Addis_Ababa     NaN         ADM4union
# 29          30      ETH-Dire_Dawa     NaN         ADM3union
# 30          31        KEN-Nairobi     NaN         ADM3union
# 31          32   MDG-Antananarivo     NaN         ADM4union
# 32          33    MEX-Mexico_City     NaN         ADM2union
# 33          34      MEX-Monterrey     NaN         ADM2union
# 34          35        RWA-Musanze     NaN         ADM5union
#
#    units_boundary_name           city_name  country_name country_code  \
# 0                 ADM3             Mendoza     Argentina          ARG
# 1                 ADM4  Mar del Plata city     Argentina          ARG
# 2                 ADM5        Ushuaia city     Argentina          ARG
# 3                 ADM3               Salta     Argentina          ARG
# 4                 ADM2        Buenos Aires     Argentina          ARG
# 5                 ADM4       Teresina city        Brazil          BRA
# 6                 ADM4       Florianopolis        Brazil          BRA
# 7                 ADM4          Belem city        Brazil          BRA
# 8                 ADM2            San Jose    Costa Rica          CRI
# 9                 ADM4              Kigali        Rwanda          RWA
# 10            ADM4city       Freetown city  Sierra Leone          SLE
# 11                ADM5           Marrakech       Morocco          MAR
# 12                ADM4      Chennai region         India          IND
# 13                ADM4               Pune          India          IND
# 14                ADM4               Surat         India          IND
# 15                ADM3             Chengdu         China          CHN
# 16                ADM3           Chongqing         China          CHN
# 17                ADM3              Ningbo         China          CHN
# 18                ADM4             Jakarta     Indonesia          IDN
# 19                ADM3              Bitung     Indonesia          IDN
# 20                ADM4            Semarang     Indonesia          IDN
# 21                ADM4          Balikpapan     Indonesia          IDN
# 22                ADM3           Palembang     Indonesia          IDN
# 23                ADM4            Salvador           NaN          BRA
# 24                ADM3              Bukavu           NaN          COD
# 25                ADM3               Uvira           NaN          COD
# 26                ADM4         Brazzaville           NaN          COG
# 27                ADM4        Barranquilla           NaN          COL
# 28                ADM4         Addis_Ababa           NaN          ETH
# 29                ADM3           Dire_Dawa           NaN          ETH
# 30                ADM3             Nairobi           NaN          KEN
# 31                ADM4        Antananarivo           NaN          MDG
# 32                ADM2         Mexico_City           NaN          MEX
# 33                ADM2           Monterrey           NaN          MEX
# 34                ADM5             Musanze           NaN          RWA
#
#    continent                          city_id    project_name  \
# 0    America        ARG-Mendoza_ADM-3-union_1      urbanshift
# 1    America        ARG-Mar_del_Plata_ADM-3_1      urbanshift
# 2    America              ARG-Ushuaia_ADM-4_1      urbanshift
# 3    America          ARG-Salta_ADM-2-union_1      urbanshift
# 4    America   ARG-Buenos_Aires_ADM-2-union_1      urbanshift
# 5    America       BRA-Teresina_ADM-4-union_1      urbanshift
# 6    America  BRA-Florianopolis_ADM-4-union_1      urbanshift
# 7    America          BRA-Belem_ADM-4-union_1      urbanshift
# 8    America       CRI-San_Jose_ADM-2-union_1      urbanshift
# 9     Africa         RWA-Kigali_ADM-4-union_1      urbanshift
# 10    Africa  SLE-Freetown_city_ADM-4-union_1      urbanshift
# 11    Africa            MAR-Marrakech_ADM-2_1      urbanshift
# 12      Asia        IND-Chennai_ADM-4-union_1      urbanshift
# 13      Asia           IND-Pune_ADM-4-union_1      urbanshift
# 14      Asia          IND-Surat_ADM-4-union_1      urbanshift
# 15      Asia        CHN-Chengdu_ADM-3-union_1      urbanshift
# 16      Asia            CHN-Chongqing_ADM-1_1      urbanshift
# 17      Asia         CHN-Ningbo_ADM-3-union_1      urbanshift
# 18      Asia        IDN-Jakarta_ADM-4-union_1      urbanshift
# 19      Asia               IDN-Bitung_ADM-2_1      urbanshift
# 20      Asia             IDN-Semarang_ADM-1_1      urbanshift
# 21      Asia     IDN-Balikpapan_ADM-4-union_1      urbanshift
# 22      Asia      IDN-Palembang_ADM-2-union_1      urbanshift
# 23       NaN        BRA-Salvador_ADM4-union_1  cities4forests
# 24       NaN          COD-Bukavu_ADM3-union_1  cities4forests
# 25       NaN           COD-Uvira_ADM3-union_1  cities4forests
# 26       NaN     COG-Brazzaville_ADM4-union_1  cities4forests
# 27       NaN    COL-Barranquilla_ADM4-union_1  cities4forests
# 28       NaN     ETH-Addis_Ababa_ADM4-union_1  cities4forests
# 29       NaN       ETH-Dire_Dawa_ADM3-union_1  cities4forests
# 30       NaN         KEN-Nairobi_ADM3-union_1  cities4forests
# 31       NaN    MDG-Antananarivo_ADM4-union_1  cities4forests
# 32       NaN     MEX-Mexico_City_ADM2-union_1  cities4forests
# 33       NaN       MEX-Monterrey_ADM2-union_1  cities4forests
# 34       NaN         RWA-Musanze_ADM5-union_1  cities4forests
#
#        city_boundary_name geo_level
# 0                     NaN       NaN
# 1                     NaN       NaN
# 2                     NaN       NaN
# 3                     NaN       NaN
# 4                     NaN       NaN
# 5                     NaN       NaN
# 6                     NaN       NaN
# 7                     NaN       NaN
# 8                     NaN       NaN
# 9                     NaN       NaN
# 10                    NaN       NaN
# 11                    NaN       NaN
# 12                    NaN       NaN
# 13                    NaN       NaN
# 14                    NaN       NaN
# 15                    NaN       NaN
# 16                    NaN       NaN
# 17                    NaN       NaN
# 18                    NaN       NaN
# 19                    NaN       NaN
# 20                    NaN       NaN
# 21                    NaN       NaN
# 22                    NaN       NaN
# 23      BRA-Salvador-ADM4      ADM4
# 24        COD-Bukavu-ADM3      ADM3
# 25         COD-Uvira-ADM3      ADM3
# 26   COG-Brazzaville-ADM4      ADM4
# 27  COL-Barranquilla-ADM4      ADM4
# 28   ETH-Addis_Ababa-ADM4      ADM4
# 29     ETH-Dire_Dawa-ADM3      ADM3
# 30       KEN-Nairobi-ADM3      ADM3
# 31  MDG-Antananarivo-ADM4      ADM4
# 32   MEX-Mexico_City-ADM2      ADM2
# 33     MEX-Monterrey-ADM2      ADM2
# 34       RWA-Musanze-ADM5      ADM5

# %%
# Convert district-boundary geojsons to Shapely polygons

def geojson_to_polygons(g):
    result = []
    for feature in g['features']:
        name = feature['properties']['geo_name']
        if type(feature['geometry']['coordinates'][0][0][0]) == list:
            coordpairs = [(float(i[0]), float(i[1])) for i in feature['geometry']['coordinates'][0][0]]
        else:
            coordpairs = [(float(i[0]), float(i[1])) for i in feature['geometry']['coordinates'][0]]
        result.append((name, Polygon(coordpairs)))
    return result

#district_polys = geojson_to_polygons(Districts_json)

# %%
# This function clips and masks raster
# Adapted from https://gis.stackexchange.com/a/387772

def mask_raster_with_geometry(raster, transform, shapes, **kwargs):
    """Wrapper for rasterio.mask.mask to allow for in-memory processing.

    Docs: https://rasterio.readthedocs.io/en/latest/api/rasterio.mask.html

    Args:
        raster (numpy.ndarray): raster to be masked with dim: [H, W]
        transform (affine.Affine): the transform of the raster
        shapes, **kwargs: passed to rasterio.mask.mask

    Returns:
        masked: numpy.ndarray or numpy.ma.MaskedArray with dim: [H, W], and new affine transform
    """
    with rasterio.io.MemoryFile() as memfile:
        with memfile.open(
            driver='GTiff',
            height=raster.shape[0],
            width=raster.shape[1],
            count=1,
            dtype=raster.dtype,
            transform=transform,
        ) as dataset:
            dataset.write(raster, 1)
        with memfile.open() as dataset:
            output, new_transform = rasterio.mask.mask(dataset, shapes, **kwargs)
    return output.squeeze(0), new_transform

# %%
# Reclassify from ESA WorldCover classes to habitat/nonhabitat

def classify_habitat(r):  # Note: order is important
    r[r == 60] = 0    # sparse veg
    r[r >= 90] = 1    # herbaceous wetland, mangrove, lichen & moss
    r[r == 80] = 0    # permanent open water
    r[r == 70] = 0    # snow/ice
    r[r == 40] = 0    # cropland
    r[r == 50] = 0    # built up
    r[r == 30] = 1    # grassland
    r[r == 20] = 1    # shrubland
    r[r == 10] = 1    # tree cover
    r[r == 0] = 0     # no data

    return r

# %%
def within_distance(rownum, gdf, sidx):
    if rownum % 1000 == 0:
        print('     {0} / {1}'.format(rownum, gdf.count().geometry))
    z = list(sidx.intersection(gdf.iloc[rownum].geometry.buffer(CONNECTIVITY_DISTANCE).bounds))  # Just look at patches in bounding box of buffered
    distances = gdf.iloc[z].distance(gdf.iloc[rownum].geometry)
    return [i for i in z if distances[i] <= CONNECTIVITY_DISTANCE if i != rownum]  # Return only those in actual buffer

# %%
def do_one_geom(row):
    print(row['geo_id'], row['geo_name'])
    geom = row[0]
    if type(geom) == MultiPolygon:
        district_poly = MultiPolygon(row[0])
    else:
        district_poly = MultiPolygon([row[0]])
    bounds = district_poly.bounds
    centroid_lon = district_poly.centroid.xy[0][0]
    centroid_lat = district_poly.centroid.xy[1][0]
    target_epsg = (32600 + [0, 100][int(centroid_lat < 0)]) + floor((180 + centroid_lon) / 6) + 1
    # EPSG is 32600 (or 32700 if lat is neg) + longitude zone. Each zone is six degrees, and first zone is 1.
    # Transform from EPSG:4326 to target EPSG
    project = pyproj.Transformer.from_crs(
        pyproj.CRS.from_epsg(4326), # source coordinate system
        pyproj.CRS.from_epsg(target_epsg), # destination coordinate system
        always_xy=True
    )
    # Get ESA WorldCover raster tiles covering AOI
    catalog = Client.open("https://planetarycomputer.microsoft.com/api/stac/v1")
    search = catalog.search(
        collections=["esa-worldcover"],
        bbox=bounds,
    )
    items = list(search.get_items())
    rasters_to_mosaic = []
    signed_hrefs = [pc.sign(i.assets["map"].href) for i in items]
    for href in signed_hrefs:
        raster = rasterio.open(href)
        rasters_to_mosaic.append(raster)

    # Stitch rasters together
    mosaic, mosaic_transform = rmerge(rasters_to_mosaic)
    # Clip raster to district boundary
    clipped_raster, clip_transform = mask_raster_with_geometry(mosaic[0], mosaic_transform, district_poly, crop=True)
    # Classify clipped raster as habitat/nonhabitat
    hab_raster = classify_habitat(clipped_raster)
    # Vectorize and collect only the habitat patches (as opposed to nonhabitat)
    with rasterio.Env():
        image = hab_raster
        results = (
        {'properties': {'raster_val': v}, 'geometry': s}
        for (s, v) 
        in shapes(image, transform=clip_transform) if v == 1)
    shapelist = list(results)
    all_patches = [  # project to UTM so that spatial unit is meter
        transform(project.transform, shape(j['geometry'])) for j in shapelist
    ]
    patches = [
        i for i in [j.simplify(100, preserve_topology=False) for j in all_patches] if i.area >= MIN_PATCHSIZE # Remove very small patches from consideration
#        j for j in all_patches if j.area >= MIN_PATCHSIZE # Remove very small patches from consideration
    ]
    patchgeoms = gpd.GeoDataFrame(geometry=patches, crs='EPSG:{}'.format(target_epsg), index=range(len(patches)))
    patchgeoms_sindex = patchgeoms.sindex


    connected = {
        j: within_distance(j, patchgeoms, patchgeoms_sindex) for j in range(len(patches))
    }
    # Find clusters from connected pairs
    edges = []
    for k in connected:
        for j in connected[k]:
            edges.append((k, j))
    G = nx.Graph()
    G.add_nodes_from(range(len(patches)))
    G.add_edges_from(edges)
    clusters = nx.connected_components(G)
    # Calculate indicator
    total_area = sum([j.area for j in patches])
    cluster_areas = []
    for k in clusters:
        cluster_areas.append(sum([patches[j].area for j in k]))
    if total_area > 0:
        return sum([j**2 for j in cluster_areas]) / (total_area**2)
    else:
        return 0

# %%
# %%time
results = []
# Some cities may have memory challenges. They can be run in batches by adjusting the range number in the following line, producing multiple OUTPUT_FILENAME files, and then combining into one.
for i in range(0,len(boundary_georef)): 
    for boundary_name in ['aoi_boundary_name', 'units_boundary_name']:
        if type(boundary_georef.loc[i, boundary_name]) != float: # sometimes boundary_id is nan
            boundary_id = boundary_georef.loc[i, 'geo_name'] + '-' + boundary_georef.loc[i, boundary_name]
            # read boundaries
            boundary_path = aws_s3_dir + boundary_ext +'boundary-'+boundary_id+'.geojson'
            boundary_geo = requests.get(boundary_path).json()
            gdf = gpd.GeoDataFrame.from_features(boundary_geo)
            gdf['BIO_2_habitat_connectivity'] = gdf.apply(do_one_geom, axis=1)
            results.append(gdf[['geo_id', 'geo_name', 'BIO_2_habitat_connectivity']].copy())
            output = pd.concat(results, axis=0)
            output.to_csv(OUTPUT_FILENAME)
# Out:
# CHN-Chongqing_ADM-1_1 CHN-Chongqing

# %%
processedcities = pd.read_csv(OUTPUT_FILENAME)
processedcities

# %%
# csv1 = pd.read_csv('BIO_2_habitat_connectivity.csv')
# csv2 = pd.read_csv('BIO_2_habitat_connectivity2.csv')
# csv3 = pd.read_csv('BIO_2_habitat_connectivity3.csv')

# processedcities = csv1.append(csv3).append(csv2)
# processedcities
# Out:
#       Unnamed: 0                     geo_id                    geo_name  \
# 0              0  ARG-Mendoza_ADM-3-union_1                 ARG-Mendoza
# 1              0        ARG-Mendoza_ADM-3_1      Distrito Las Barrancas
# 2              1        ARG-Mendoza_ADM-3_2          Distrito San Roque
# 3              2        ARG-Mendoza_ADM-3_3  Distrito Fray Luis Beltrán
# 4              3        ARG-Mendoza_ADM-3_4    Distrito Rodeo del Medio
# ...          ...                        ...                         ...
# 1528          82        RWA-Musanze_ADM5_83                    Kamajaga
# 1529          83        RWA-Musanze_ADM5_84                    Kamicaca
# 1530          84        RWA-Musanze_ADM5_85                     Musenyi
# 1531          85        RWA-Musanze_ADM5_86                      Rugari
# 1532          86        RWA-Musanze_ADM5_87                     Burengo
#
#       BIO_2_habitat_connectivity
# 0                       0.407088
# 1                       0.641266
# 2                       0.227415
# 3                       0.387826
# 4                       0.145720
# ...                          ...
# 1528                    1.000000
# 1529                    0.889280
# 1530                    1.000000
# 1531                    1.000000
# 1532                    1.000000
#
# [2628 rows x 4 columns]

# %% [markdown]
# # Merge with indicator table

# %%
# read indicator table
cities_indicators = pd.read_csv(aws_s3_dir +'/'+ indicators_file_aws)
cities_indicators
# Out:
#                          geo_id    geo_level                    geo_name  \
# 0     ARG-Mendoza_ADM-3-union_1  ADM-3-union                 ARG-Mendoza
# 1           ARG-Mendoza_ADM-3_1        ADM-3      Distrito Las Barrancas
# 2           ARG-Mendoza_ADM-3_2        ADM-3          Distrito San Roque
# 3           ARG-Mendoza_ADM-3_3        ADM-3  Distrito Fray Luis Beltrán
# 4           ARG-Mendoza_ADM-3_4        ADM-3    Distrito Rodeo del Medio
# ...                         ...          ...                         ...
# 2623        RWA-Musanze_ADM5_83         ADM5                    Kamajaga
# 2624        RWA-Musanze_ADM5_84         ADM5                    Kamicaca
# 2625        RWA-Musanze_ADM5_85         ADM5                     Musenyi
# 2626        RWA-Musanze_ADM5_86         ADM5                      Rugari
# 2627        RWA-Musanze_ADM5_87         ADM5                     Burengo
#
#      geo_parent_name  HEA_1_percentChangeinDaysAbove35C2020to2050  \
# 0        ARG-Mendoza                                          0.0
# 1        ARG-Mendoza                                          NaN
# 2        ARG-Mendoza                                          NaN
# 3        ARG-Mendoza                                          NaN
# 4        ARG-Mendoza                                          NaN
# ...              ...                                          ...
# 2623     RWA-Musanze                                          NaN
# 2624     RWA-Musanze                                          NaN
# 2625     RWA-Musanze                                          NaN
# 2626     RWA-Musanze                                          NaN
# 2627     RWA-Musanze                                          NaN
#
#       HEA_4_percentBuiltupWithoutTreeCover  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2623                              0.993718
# 2624                              0.995015
# 2625                              0.983103
# 2626                              0.952790
# 2627                              0.995930
#
#       HEA_2_percentBuiltupwHighLST-2013to2022meanofmonthwhottestday  \
# 0                                              0.306981
# 1                                              0.317241
# 2                                              0.005444
# 3                                              0.204788
# 4                                              0.126250
# ...                                                 ...
# 2623                                           0.078125
# 2624                                           0.125000
# 2625                                           0.280000
# 2626                                           0.000000
# 2627                                           0.065934
#
#       ACC_2_percentOpenSpaceinBuiltup2022  \
# 0                                0.037594
# 1                                0.006540
# 2                                0.006642
# 3                                0.007968
# 4                                0.005204
# ...                                   ...
# 2623                             0.000000
# 2624                             0.000000
# 2625                             0.000000
# 2626                             0.000000
# 2627                             0.000000
#
#       ACC_1_OpenSpaceHectaresper1000people2022  \
# 0                                   350.814444
# 1                                     1.972102
# 2                                     0.128004
# 3                                     0.194904
# 4                                     0.329989
# ...                                        ...
# 2623                                  0.000000
# 2624                                  0.000000
# 2625                                  0.000000
# 2626                                  0.000000
# 2627                                  0.000000
#
#       FLD_2_percentChangeinMaxDailyPrecip2020to2050  ...  \
# 0                                         -0.041587  ...
# 1                                               NaN  ...
# 2                                               NaN  ...
# 3                                               NaN  ...
# 4                                               NaN  ...
# ...                                             ...  ...
# 2623                                            NaN  ...
# 2624                                            NaN  ...
# 2625                                            NaN  ...
# 2626                                            NaN  ...
# 2627                                            NaN  ...
#
#       FLD_3_percentBuiltupWithin1mAboveDrainage  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2623                                   0.000000
# 2624                                   0.000000
# 2625                                   0.013621
# 2626                                   0.001839
# 2627                                   0.011839
#
#       FLD_7_percentSteepSlopesWOvegetationcover2020  \
# 0                                          0.991441
# 1                                          0.500000
# 2                                          0.000000
# 3                                          0.000000
# 4                                          0.642857
# ...                                             ...
# 2623                                       0.000000
# 2624                                       0.000000
# 2625                                       0.000000
# 2626                                       0.000000
# 2627                                       0.000000
#
#       FLD_6_percentRiparianZonewoVegorWatercover2020  \
# 0                                           0.834118
# 1                                           0.642378
# 2                                           0.448561
# 3                                           0.504732
# 4                                           0.399084
# ...                                              ...
# 2623                                        0.006873
# 2624                                        0.000000
# 2625                                        0.039106
# 2626                                        0.000000
# 2627                                        0.031915
#
#       AQ_3_percentWHOlimitPM25exposure2020  \
# 0                               395.468104
# 1                               421.848765
# 2                               418.691308
# 3                               443.270436
# 4                               435.658329
# ...                                    ...
# 2623                            747.936003
# 2624                            753.422329
# 2625                            754.165614
# 2626                            745.213966
# 2627                            779.657119
#
#       GHG_2_meanannualTreeCarbonFluxMgcO2eperHA  BIO_1_percentNaturalArea  \
# 0                                     -0.003951                  0.340102
# 1                                     -0.000560                  0.422282
# 2                                     -0.000316                  0.286480
# 3                                     -0.001430                  0.282508
# 4                                     -0.001232                  0.185538
# ...                                         ...                       ...
# 2623                                  -6.014612                  0.321897
# 2624                                  -9.194192                  0.536051
# 2625                                  -2.157699                  0.214939
# 2626                                  -1.362025                  0.488671
# 2627                                  -3.595113                  0.696620
#
#       LND_1_percentPermeableSurface  LND_2_percentTreeCover  \
# 0                          0.982321                     NaN
# 1                          0.998457                     NaN
# 2                          0.976852                     NaN
# 3                          0.984147                     NaN
# 4                          0.964504                     NaN
# ...                             ...                     ...
# 2623                       1.000000                0.233365
# 2624                       1.000000                0.372657
# 2625                       1.000000                0.167535
# 2626                       0.983759                0.256713
# 2627                       0.998029                0.285268
#
#       LND_4_percentof2000HabitatAreaRestoredby2020  \
# 0                                         0.011921
# 1                                         0.150528
# 2                                         0.167138
# 3                                         0.095692
# 4                                         0.101342
# ...                                            ...
# 2623                                      0.004286
# 2624                                      0.047648
# 2625                                      0.000000
# 2626                                      0.000000
# 2627                                      0.165747
#
#       LND_5_numberofHabitatTypesRestoredby2020
# 0                                     1.000000
# 1                                     0.400000
# 2                                     0.600000
# 3                                     0.833333
# 4                                     0.833333
# ...                                        ...
# 2623                                  1.000000
# 2624                                  1.000000
# 2625                                  0.000000
# 2626                              -9999.000000
# 2627                                  1.000000
#
# [2628 rows x 24 columns]

# %%
def merge_indicators(indicator_table, new_indicator_table, indicator_name):
    if indicator_name in indicator_table.columns:
        print("replace with new calculations")
        indicator_table.drop(indicator_name, inplace=True, axis=1)
        cities_indicators_df = indicator_table.merge(new_indicator_table[["geo_id",indicator_name]], 
                                                     on='geo_id', 
                                                     how='left')
    else:
        print("add new indicators")
        cities_indicators_df = indicator_table.merge(new_indicator_table[["geo_id",indicator_name]], 
                                                     on='geo_id', 
                                                     how='left')
    return(cities_indicators_df)

# %%
cities_indicators_merged = merge_indicators(indicator_table = cities_indicators,
                                            new_indicator_table = processedcities,
                                            indicator_name = 'BIO_2_habitat_connectivity')
# Out:
# add new indicators

# %%
cities_indicators_merged
# Out:
#                          geo_id    geo_level                    geo_name  \
# 0     ARG-Mendoza_ADM-3-union_1  ADM-3-union                 ARG-Mendoza
# 1           ARG-Mendoza_ADM-3_1        ADM-3      Distrito Las Barrancas
# 2           ARG-Mendoza_ADM-3_2        ADM-3          Distrito San Roque
# 3           ARG-Mendoza_ADM-3_3        ADM-3  Distrito Fray Luis Beltrán
# 4           ARG-Mendoza_ADM-3_4        ADM-3    Distrito Rodeo del Medio
# ...                         ...          ...                         ...
# 2623        RWA-Musanze_ADM5_83         ADM5                    Kamajaga
# 2624        RWA-Musanze_ADM5_84         ADM5                    Kamicaca
# 2625        RWA-Musanze_ADM5_85         ADM5                     Musenyi
# 2626        RWA-Musanze_ADM5_86         ADM5                      Rugari
# 2627        RWA-Musanze_ADM5_87         ADM5                     Burengo
#
#      geo_parent_name  HEA_1_percentChangeinDaysAbove35C2020to2050  \
# 0        ARG-Mendoza                                          0.0
# 1        ARG-Mendoza                                          NaN
# 2        ARG-Mendoza                                          NaN
# 3        ARG-Mendoza                                          NaN
# 4        ARG-Mendoza                                          NaN
# ...              ...                                          ...
# 2623     RWA-Musanze                                          NaN
# 2624     RWA-Musanze                                          NaN
# 2625     RWA-Musanze                                          NaN
# 2626     RWA-Musanze                                          NaN
# 2627     RWA-Musanze                                          NaN
#
#       HEA_4_percentBuiltupWithoutTreeCover  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2623                              0.993718
# 2624                              0.995015
# 2625                              0.983103
# 2626                              0.952790
# 2627                              0.995930
#
#       HEA_2_percentBuiltupwHighLST-2013to2022meanofmonthwhottestday  \
# 0                                              0.306981
# 1                                              0.317241
# 2                                              0.005444
# 3                                              0.204788
# 4                                              0.126250
# ...                                                 ...
# 2623                                           0.078125
# 2624                                           0.125000
# 2625                                           0.280000
# 2626                                           0.000000
# 2627                                           0.065934
#
#       ACC_2_percentOpenSpaceinBuiltup2022  \
# 0                                0.037594
# 1                                0.006540
# 2                                0.006642
# 3                                0.007968
# 4                                0.005204
# ...                                   ...
# 2623                             0.000000
# 2624                             0.000000
# 2625                             0.000000
# 2626                             0.000000
# 2627                             0.000000
#
#       ACC_1_OpenSpaceHectaresper1000people2022  \
# 0                                   350.814444
# 1                                     1.972102
# 2                                     0.128004
# 3                                     0.194904
# 4                                     0.329989
# ...                                        ...
# 2623                                  0.000000
# 2624                                  0.000000
# 2625                                  0.000000
# 2626                                  0.000000
# 2627                                  0.000000
#
#       FLD_2_percentChangeinMaxDailyPrecip2020to2050  ...  \
# 0                                         -0.041587  ...
# 1                                               NaN  ...
# 2                                               NaN  ...
# 3                                               NaN  ...
# 4                                               NaN  ...
# ...                                             ...  ...
# 2623                                            NaN  ...
# 2624                                            NaN  ...
# 2625                                            NaN  ...
# 2626                                            NaN  ...
# 2627                                            NaN  ...
#
#       FLD_7_percentSteepSlopesWOvegetationcover2020  \
# 0                                          0.991441
# 1                                          0.500000
# 2                                          0.000000
# 3                                          0.000000
# 4                                          0.642857
# ...                                             ...
# 2623                                       0.000000
# 2624                                       0.000000
# 2625                                       0.000000
# 2626                                       0.000000
# 2627                                       0.000000
#
#       FLD_6_percentRiparianZonewoVegorWatercover2020  \
# 0                                           0.834118
# 1                                           0.642378
# 2                                           0.448561
# 3                                           0.504732
# 4                                           0.399084
# ...                                              ...
# 2623                                        0.006873
# 2624                                        0.000000
# 2625                                        0.039106
# 2626                                        0.000000
# 2627                                        0.031915
#
#       AQ_3_percentWHOlimitPM25exposure2020  \
# 0                               395.468104
# 1                               421.848765
# 2                               418.691308
# 3                               443.270436
# 4                               435.658329
# ...                                    ...
# 2623                            747.936003
# 2624                            753.422329
# 2625                            754.165614
# 2626                            745.213966
# 2627                            779.657119
#
#       GHG_2_meanannualTreeCarbonFluxMgcO2eperHA  BIO_1_percentNaturalArea  \
# 0                                     -0.003951                  0.340102
# 1                                     -0.000560                  0.422282
# 2                                     -0.000316                  0.286480
# 3                                     -0.001430                  0.282508
# 4                                     -0.001232                  0.185538
# ...                                         ...                       ...
# 2623                                  -6.014612                  0.321897
# 2624                                  -9.194192                  0.536051
# 2625                                  -2.157699                  0.214939
# 2626                                  -1.362025                  0.488671
# 2627                                  -3.595113                  0.696620
#
#       LND_1_percentPermeableSurface  LND_2_percentTreeCover  \
# 0                          0.982321                     NaN
# 1                          0.998457                     NaN
# 2                          0.976852                     NaN
# 3                          0.984147                     NaN
# 4                          0.964504                     NaN
# ...                             ...                     ...
# 2623                       1.000000                0.233365
# 2624                       1.000000                0.372657
# 2625                       1.000000                0.167535
# 2626                       0.983759                0.256713
# 2627                       0.998029                0.285268
#
#       LND_4_percentof2000HabitatAreaRestoredby2020  \
# 0                                         0.011921
# 1                                         0.150528
# 2                                         0.167138
# 3                                         0.095692
# 4                                         0.101342
# ...                                            ...
# 2623                                      0.004286
# 2624                                      0.047648
# 2625                                      0.000000
# 2626                                      0.000000
# 2627                                      0.165747
#
#       LND_5_numberofHabitatTypesRestoredby2020  BIO_2_habitat_connectivity
# 0                                     1.000000                    0.407088
# 1                                     0.400000                    0.641266
# 2                                     0.600000                    0.227415
# 3                                     0.833333                    0.387826
# 4                                     0.833333                    0.145720
# ...                                        ...                         ...
# 2623                                  1.000000                    1.000000
# 2624                                  1.000000                    0.889280
# 2625                                  0.000000                    1.000000
# 2626                              -9999.000000                    1.000000
# 2627                                  1.000000                    1.000000
#
# [2628 rows x 25 columns]

# %% [markdown]
# ## Upload in aws s3

# %%
# connect to s3
aws_credentials = pd.read_csv('/home/jovyan/PlanetaryComputerExamples/aws_credentials.csv')
aws_key = aws_credentials.iloc[0]['Access key ID']
aws_secret = aws_credentials.iloc[0]['Secret access key']

s3 = boto3.resource(
    service_name='s3',
    aws_access_key_id=aws_key,
    aws_secret_access_key=aws_secret
)

# %%
# upload to aws
key_data = indicators_file_aws
cities_indicators_merged.to_csv(
    f"s3://{bucket_name}/{key_data}",
    index=False,
    storage_options={
        "key": aws_key,
        "secret": aws_secret
    },
)

# %%
# make it public
object_acl = s3.ObjectAcl(bucket_name,key_data)
response = object_acl.put(ACL='public-read')
